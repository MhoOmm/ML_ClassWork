# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
X = df.iloc[:,1:3]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import LabelEncoder
ln = LabelEncoder()
y = ln.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=3,test_size=0.2)
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion='gini',splitter='best',max_depth=5,max_leaf_nodes=5)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_leaf_nodes=5)

# %%
dt.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': None,
#  'max_leaf_nodes': 5,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
y_pred = dt.predict(X_test)
from sklearn.metrics import accuracy_score
print("Acc:",accuracy_score(y_pred,y_test))
# Out:
# Acc: 0.7666666666666667

# %%
from sklearn.tree import plot_tree
plot_tree(dt)
# Out:
# [Text(0.5, 0.875, 'x[0] <= 5.55\ngini = 0.667\nsamples = 120\nvalue = [40, 40, 40]'),
#  Text(0.25, 0.625, 'x[1] <= 2.8\ngini = 0.317\nsamples = 47\nvalue = [38, 8, 1]'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'gini = 0.37\nsamples = 9\nvalue = [1, 7, 1]'),
#  Text(0.375, 0.375, 'gini = 0.051\nsamples = 38\nvalue = [37, 1, 0]'),
#  Text(0.75, 0.625, 'x[0] <= 6.25\ngini = 0.522\nsamples = 73\nvalue = [2, 32, 39]'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[1] <= 3.6\ngini = 0.478\nsamples = 33\nvalue = [2, 22, 9]'),
#  Text(0.5, 0.125, 'gini = 0.412\nsamples = 31\nvalue = [0, 22, 9]'),
#  Text(0.75, 0.125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.875, 0.375, 'gini = 0.375\nsamples = 40\nvalue = [0, 10, 30]')]
