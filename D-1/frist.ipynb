# %%
import csv
import random
fname = "employees.csv"

col= ['id', 'age', 'salary', 'score', 'rating']

rows = []
for i in range(1, 11):
    record = [
        i,
        random.randint(10, 50), 
        random.randint(30000, 120000),
        random.randint(0, 100),
        random.randint(1, 5) 
    ]
    rows.append(record)

with open(fname, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(col)      
    writer.writerows(rows)     

print("CSV file created")
# Out:
# CSV file created
